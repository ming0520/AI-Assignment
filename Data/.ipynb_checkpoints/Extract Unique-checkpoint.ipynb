# %%
import pandas as pd
file_name = "20201018_v2_lower_clean_brand"
file_type = ".csv"
ds= pd.read_csv("20201018.csv")

# %%
ds_header = ds.columns.tolist()

# %%
ds_unique = {}
for i in ds_header:
    print("Unique for", i)
    print(ds[i].unique())
    ds_unique[i] = ds[i].unique()
    print("===End==\n")
# Out:
# Unique for colour
# ['Multicolour or gradient' 'Red' 'Blue' 'Black' 'Green' 'non' 'White'
#  'Pink' 'White ' 'black' 'Purple' 'Transparent' 'Gateron Yellow'
#  'Black and pink' 'Teal' 'Cyan' 'Clean color design' 'Black ' 'Yellow'
#  'Orange' 'Lilac pink']
# ===End==
#
# Unique for layout
# ['Compact, 75%' 'TKL, 87%-88% (87-88 key)' 'Super Compact, 60%'
#  'Full Size, 100% (more than 104 key)' 'Split Columnar Staggered ' '65%'
#  '96%' 'Split Ergo' 'both full size (104/108/114) and compact 75%']
# ===End==
#
# Unique for low_profile
# ['Low profile (slim)' 'Non low-profile' 'High Profile' 'no preference'
#  'Maybe']
# ===End==
#
# Unique for backlight
# ['Yes' 'No' 'Maybe' nan]
# ===End==
#
# Unique for switch
# [nan 'Linear - Red - Fast, Quite, Light' 'Tactile'
#  'Linear - Black - Fast, Quite, Heavy' 'Clicky - Blue' 'Romer G'
#  'Optical Switch']
# ===End==
#
# Unique for top3_keyboard
# ['ROG Strix Flare PNK LTD, ROG Strix Scope TKL Electro Punk and ROG Strix Flare'
#  'HyperX, Razer, RedDragon' 'MSI, RAZER, ROG'
#  'Logitech Wireless K400 plus, Logitech K360, Apple Magic Keyboard'
#  '1.Logitech G Pro X.\n2.Logitech G915\n3.Logitech MX Keys.'
#  'Logitech, Targus, Fantech' nan 'razer'
#  'Preference on custom keyboards, therefore no models/brands to answer with.'
#  'topre real force , ducky , filco'
#  'Rama U80-A, HHKB type S, Realforce 87u'
#  'Rama U80A, Leopold fc660c, Tofu 65'
#  'Ducky one 2 mini, custom mechanical keyboard, razer huntsman'
#  'Razer, Logitech, ASUS' 'leopold fc989m, kbdfan bella, tofu'
#  'TGR, SINGA, OTD' 'Rama M60, HHKB, Keycult'
#  'Logitech g513, tecware phantom elite, GSkill KM360'
#  'Melody96, Vega, Keycult No. 1/65 Rev. 1' 'KBD75, Think 6.5 v2, NK65'
#  'Tecware Phantom Elite TKL\nGK61X\nGK64XS ' 'Keychron K2, GK61, RK61'
#  '- ' 'Iron165,Andromeda,Think65 V2' 'Cyberboard, GK61, Huntsman Mini'
#  'Custom build boards' 'Dz60v2 pcb, gk64s, leopold fc660c'
#  '1. Topre Realforce 45g Uniform\n2. Smith + Rune Iron165\n3. TGR x Singa Unikorn'
#  'Royal Kludge RK61' 'dell, hp, fujitsu' 'Keycult, Vega, RAMA koyu'
#  'kemove 61, anne pro 2, varmilo sakura'
#  'Keychron K2, Vortexgear Race 3, Ducky One 2 Mini' 'Tofu65, Arisu, Singa'
#  'Cyberboard, GK61, RK61' 'Keychron'
#  'HHKB Hybrid Type-S\nAcrylic Alice\nPolycarb Canoe'
#  'Logitech g915\nCorsair k95 platinum mk2\nGeek gk68xs'
#  'Tofu 60%, NK65V2, GK61x' 'Kbd75'
#  'Leopold Fc980m, cherry g80-1800, tgr alice' 'Vortex Tab 75, KBD75, XD84'
#  'Never research on this before sorry' 'Leopold, ducky, custom'
#  'Razer huntsman mini\nDucky one mini\nSkyloong gk61'
#  'Hubble65, Fuji65, Constellation' 'Tofu65, Qlavier acrylic, Rama Koyu '
#  'Anne Pro 2, Tecware Phantom TKL, Cooler Master MK730'
#  'TGR Alice, TGR Jane, Keycult Custom'
#  'Steelseries apex m260, Phantom Tecware TKL & Ducky One 2 Mini'
#  'Hhkb, keeblade, kbdfans tofu'
#  'Tofu60, Hexgear Gemini Dusk, custom keyboard' 'VZTEC'
#  'Think 6.5, Mark 65, Titan 65' 'Kemove Shadow 61\nDucky\nFilco'
#  'gk61s, anne pro 2' 'Ducky One 2 mini,Hhkb,Dz60'
#  'Topre HHKB2, Vortex Poker 2, Custom.'
#  'Ducky one 2 mini, IBM Model M, HHKB'
#  'Discipline 65, IBM Model M, and Tofu65'
#  'Tecware Phantom Elite 87. Wormier K66. Epomaker GK64']
# ===End==
#
# Unique for dream_keyboard
# ['Logitech K380 multi-device bluetooth keyboard'
#  'Linear Reds with metal frame'
#  'Keyboard that can play game, and foldable. ' 'do not have one. '
#  'Das Keyboard Prime 13' 'Logitech K400' 'ROG'
#  'RAZER BLACKWIDOW V3 PRO WIRELESS MECHANICAL GAMING KEYBOARD - BLACK'
#  '7V' 'topre ivory 55g TKL' 'Rama U80-A'
#  'Make my very own custom keyboard ' 'Razer' 'keycult no.2' 'OTD 356CL'
#  'Rama M60, Alpaca, brass plate, GMK '
#  'Tecware Phantom Elite with Gateron Yellows' 'Keycult No. 1/65 Rev. 1'
#  'Satisfaction 75' nan 'Steelseries Apex Pro TKL' 'Kyuu'
#  'No idea as long as it is pink colour and light' 'Andromeda' 'Cyberboard'
#  'G2 Pengu with Zealios 67g or c3 Tangarines, Screw mount stabs'
#  'Keycult no2/65' 'Keycult No. 1 Rev. 2 TKL'
#  'Im not really care what my dream keyboard is. Just using what i have..if i have money, i buy the better one????'
#  'logitech membrane keyboard' 'AI03 Vega' 'a custom ergo kb'
#  'Vortexgear Race 3' 'Tgr x Singa'
#  'Kyuu (For aesthetic reasons and nothing else ??)'
#  'Custom keyboard gk68xs with cream switch' 'NK65v2' 'Kbd75'
#  '40% with southpaw tenkey (self custom made)'
#  'any tactile switch, high profile non floating switch, fully aluminium chassis/frame, PBT Cherry Profile Keycaps as its standard stock'
#  'Never research before as well' 'Norbaforce'
#  "Tfue's keyboard worth $3500" 'Iron165 FE' 'razer' 'Keycult No1/65'
#  'Keycult Custom Design Keyboard' 'a premium custom build keyboard'
#  'Ai03 Vega' 'KBD75 with lubed NK Creams ' 'Tex shinobi' 'GK73'
#  'Tofu Dz60' 'Rama Custom 60%' 'Keycult No.1/65' 'SINGA V3']
# ===End==
#
# Unique for usecase
# [nan 'Home' 'Office' 'E-sport' 'Both Home and Office' 'Everywhere']
# ===End==
#
# Unique for using_keyboard
# [nan 'Lenovo ideapad s410 laptop keyboard' 'Norbatouch'
#  'Royal klugde rk61' 'Polycarbonate GK64XS ' 'razer' 'Tofu65' 'GK64xs'
#  'Phantom Tecware TKL with linear switches' 'Hhkb pro 2'
#  'Hexgear gemini dusk, Tofu60' 'Razor' 'VZTEC' 'GK61X' 'AKKO 3084 '
#  'Kemove Shadow61' 'gk61s' 'Gk61' 'KBDFan Tofu 60% T2 switches.'
#  'Logitech G413 Carbon' 'Discipline 65 and Ducky One 2 Mini'
#  'Tecware Phantom Elite 87']
# ===End==

# %%
print(ds_unique)
# Out:
# {'colour': array(['Multicolour or gradient', 'Red', 'Blue', 'Black', 'Green', 'non',
#        'White', 'Pink', 'White ', 'black', 'Purple', 'Transparent',
#        'Gateron Yellow', 'Black and pink', 'Teal', 'Cyan',
#        'Clean color design', 'Black ', 'Yellow', 'Orange', 'Lilac pink'],
#       dtype=object), 'layout': array(['Compact, 75%', 'TKL, 87%-88% (87-88 key)', 'Super Compact, 60%',
#        'Full Size, 100% (more than 104 key)', 'Split Columnar Staggered ',
#        '65%', '96%', 'Split Ergo',
#        'both full size (104/108/114) and compact 75%'], dtype=object), 'low_profile': array(['Low profile (slim)', 'Non low-profile', 'High Profile',
#        'no preference', 'Maybe'], dtype=object), 'backlight': array(['Yes', 'No', 'Maybe', nan], dtype=object), 'switch': array([nan, 'Linear - Red - Fast, Quite, Light', 'Tactile',
#        'Linear - Black - Fast, Quite, Heavy', 'Clicky - Blue', 'Romer G',
#        'Optical Switch'], dtype=object), 'top3_keyboard': array(['ROG Strix Flare PNK LTD, ROG Strix Scope TKL Electro Punk and ROG Strix Flare',
#        'HyperX, Razer, RedDragon', 'MSI, RAZER, ROG',
#        'Logitech Wireless K400 plus, Logitech K360, Apple Magic Keyboard',
#        '1.Logitech G Pro X.\n2.Logitech G915\n3.Logitech MX Keys.',
#        'Logitech, Targus, Fantech', nan, 'razer',
#        'Preference on custom keyboards, therefore no models/brands to answer with.',
#        'topre real force , ducky , filco',
#        'Rama U80-A, HHKB type S, Realforce 87u',
#        'Rama U80A, Leopold fc660c, Tofu 65',
#        'Ducky one 2 mini, custom mechanical keyboard, razer huntsman',
#        'Razer, Logitech, ASUS', 'leopold fc989m, kbdfan bella, tofu',
#        'TGR, SINGA, OTD', 'Rama M60, HHKB, Keycult',
#        'Logitech g513, tecware phantom elite, GSkill KM360',
#        'Melody96, Vega, Keycult No. 1/65 Rev. 1',
#        'KBD75, Think 6.5 v2, NK65',
#        'Tecware Phantom Elite TKL\nGK61X\nGK64XS ',
#        'Keychron K2, GK61, RK61', '- ', 'Iron165,Andromeda,Think65 V2',
#        'Cyberboard, GK61, Huntsman Mini', 'Custom build boards',
#        'Dz60v2 pcb, gk64s, leopold fc660c',
#        '1. Topre Realforce 45g Uniform\n2. Smith + Rune Iron165\n3. TGR x Singa Unikorn',
#        'Royal Kludge RK61', 'dell, hp, fujitsu',
#        'Keycult, Vega, RAMA koyu',
#        'kemove 61, anne pro 2, varmilo sakura',
#        'Keychron K2, Vortexgear Race 3, Ducky One 2 Mini',
#        'Tofu65, Arisu, Singa', 'Cyberboard, GK61, RK61', 'Keychron',
#        'HHKB Hybrid Type-S\nAcrylic Alice\nPolycarb Canoe',
#        'Logitech g915\nCorsair k95 platinum mk2\nGeek gk68xs',
#        'Tofu 60%, NK65V2, GK61x', 'Kbd75',
#        'Leopold Fc980m, cherry g80-1800, tgr alice',
#        'Vortex Tab 75, KBD75, XD84',
#        'Never research on this before sorry', 'Leopold, ducky, custom',
#        'Razer huntsman mini\nDucky one mini\nSkyloong gk61',
#        'Hubble65, Fuji65, Constellation',
#        'Tofu65, Qlavier acrylic, Rama Koyu ',
#        'Anne Pro 2, Tecware Phantom TKL, Cooler Master MK730',
#        'TGR Alice, TGR Jane, Keycult Custom',
#        'Steelseries apex m260, Phantom Tecware TKL & Ducky One 2 Mini',
#        'Hhkb, keeblade, kbdfans tofu',
#        'Tofu60, Hexgear Gemini Dusk, custom keyboard', 'VZTEC',
#        'Think 6.5, Mark 65, Titan 65', 'Kemove Shadow 61\nDucky\nFilco',
#        'gk61s, anne pro 2', 'Ducky One 2 mini,Hhkb,Dz60',
#        'Topre HHKB2, Vortex Poker 2, Custom.',
#        'Ducky one 2 mini, IBM Model M, HHKB',
#        'Discipline 65, IBM Model M, and Tofu65',
#        'Tecware Phantom Elite 87. Wormier K66. Epomaker GK64'],
#       dtype=object), 'dream_keyboard': array(['Logitech K380 multi-device bluetooth keyboard',
#        'Linear Reds with metal frame',
#        'Keyboard that can play game, and foldable. ', 'do not have one. ',
#        'Das Keyboard Prime 13', 'Logitech K400', 'ROG',
#        'RAZER BLACKWIDOW V3 PRO WIRELESS MECHANICAL GAMING KEYBOARD - BLACK',
#        '7V', 'topre ivory 55g TKL', 'Rama U80-A',
#        'Make my very own custom keyboard ', 'Razer', 'keycult no.2',
#        'OTD 356CL', 'Rama M60, Alpaca, brass plate, GMK ',
#        'Tecware Phantom Elite with Gateron Yellows',
#        'Keycult No. 1/65 Rev. 1', 'Satisfaction 75', nan,
#        'Steelseries Apex Pro TKL', 'Kyuu',
#        'No idea as long as it is pink colour and light', 'Andromeda',
#        'Cyberboard',
#        'G2 Pengu with Zealios 67g or c3 Tangarines, Screw mount stabs',
#        'Keycult no2/65', 'Keycult No. 1 Rev. 2 TKL',
#        'Im not really care what my dream keyboard is. Just using what i have..if i have money, i buy the better one????',
#        'logitech membrane keyboard', 'AI03 Vega', 'a custom ergo kb',
#        'Vortexgear Race 3', 'Tgr x Singa',
#        'Kyuu (For aesthetic reasons and nothing else ??)',
#        'Custom keyboard gk68xs with cream switch', 'NK65v2', 'Kbd75',
#        '40% with southpaw tenkey (self custom made)',
#        'any tactile switch, high profile non floating switch, fully aluminium chassis/frame, PBT Cherry Profile Keycaps as its standard stock',
#        'Never research before as well', 'Norbaforce',
#        "Tfue's keyboard worth $3500", 'Iron165 FE', 'razer',
#        'Keycult No1/65', 'Keycult Custom Design Keyboard',
#        'a premium custom build keyboard', 'Ai03 Vega',
#        'KBD75 with lubed NK Creams ', 'Tex shinobi', 'GK73', 'Tofu Dz60',
#        'Rama Custom 60%', 'Keycult No.1/65', 'SINGA V3'], dtype=object), 'usecase': array([nan, 'Home', 'Office', 'E-sport', 'Both Home and Office',
#        'Everywhere'], dtype=object), 'using_keyboard': array([nan, 'Lenovo ideapad s410 laptop keyboard', 'Norbatouch',
#        'Royal klugde rk61', 'Polycarbonate GK64XS ', 'razer', 'Tofu65',
#        'GK64xs', 'Phantom Tecware TKL with linear switches', 'Hhkb pro 2',
#        'Hexgear gemini dusk, Tofu60', 'Razor', 'VZTEC', 'GK61X',
#        'AKKO 3084 ', 'Kemove Shadow61', 'gk61s', 'Gk61',
#        'KBDFan Tofu 60% T2 switches.', 'Logitech G413 Carbon',
#        'Discipline 65 and Ducky One 2 Mini', 'Tecware Phantom Elite 87'],
#       dtype=object)}

# %%
# pd.DataFrame(ds_unique['colour'], columns=['colour'])
df_list = []
for i in ds_header:
    df = pd.DataFrame(ds_unique[i], columns=[i])
    df_list.append(df)
#     df.to_csv(f'{i}.csv')

# %%
writer = pd.ExcelWriter('file.xlsx')
for i, df in enumerate(df_list):
     df.to_excel(writer,f'{ds_header[i]}')
writer.save()
